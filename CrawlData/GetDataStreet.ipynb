# %%
#import thư viện
from cmath import nan
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler , RobustScaler, StandardScaler
import warnings
import re
import time
from tqdm import tqdm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
warnings.filterwarnings("ignore")

# %% [markdown]
# # Đọc dữ liệu

# %%
#dataset1
df1=pd.read_excel('sample_data/streetname.xlsx')
df1
# df1.describe()
# df1.info()
# Out:
#               Tên đường                            Từ khóa  \
# 0                   3/2                3 tháng 2, Hải Châu
# 1                  30/4               30 tháng 4, Hải Châu
# 2                   2/9  2 tháng 9, Hải Châu, quốc khánh,
# 3            Liên Chiểu         Phan Đinh Ngót, liên chiểu
# 4           Lý Tế Xuyên                        Lý Tế Xuyên
# ...                 ...                                ...
# 1832  Yên Báy (Yên Bái)        Yên Báy (Yên Bái); Hải Châu
# 1833          Yên Khê 1                          Yên Khê 1
# 1834          Yên Khê 2                          Yên Khê 2
# 1835            Yên Thế           Yên Thế; Hòa An; Cẩm Lệ
# 1836           Yết Kiêu      Yết Kiêu; Thọ Quang; Sơn Trà
#
#                                                   Mô tả
# 0     TÊN ĐƯỜNG: 3 tháng 2\n* Vị trí con đường:\n1. ...
# 1     TÊN ĐƯỜNG: 30 tháng 4\n* Vị trí con đường:\n1....
# 2     TÊN ĐƯỜNG: 2 tháng 9\n* Vị trí con đường:\n1. ...
# ...

# %% [markdown]
# Hàm lấy chiều rộng đường

# %%
def getStreetWitdh(content):
  contentArray = content.split("\n")
  for item in contentArray:
    if(item.find("Chiều rộng") != -1):
      return item.replace("2. Chiều rộng", "").replace(":", "")
  return ""

# %% [markdown]
# Lấy tên đường và chiều rộng sau đó đổi tên cột

# %%
dataStreet = df1[['Mô tả', 'Tên đường']]
dataStreet['Tên đường'] = dataStreet['Tên đường'].apply(lambda x: "Phan Đình Giót" if(x == "Liên Chiểu") else x)
dataStreet['Mô tả'] = dataStreet['Mô tả'].apply(lambda x: getStreetWitdh(x) if(x != "" and type(x) == str) else x)
dataStreet["STT"] = dataStreet.index + 1
dataStreet.rename(columns={'Mô tả':'width'}, inplace=True)
dataStreet.rename(columns={'Tên đường':'name'}, inplace=True)
dataStreet
# Out:
#                   width               name   STT
# 0                 27,5m                3/2     1
# 1                   34m               30/4     2
# 2                   21m                2/9     3
# 3                 7.5 m         Liên Chiểu     4
# 4                 5,5 m        Lý Tế Xuyên     5
# ...                 ...                ...   ...
# 1832                 7m  Yên Báy (Yên Bái)  1833
# 1833             5,5m            Yên Khê 1  1834
# 1834    7.5m - 5.5m m            Yên Khê 2  1835
# 1835              7,5 m            Yên Thế  1836
# 1836               24 m           Yết Kiêu  1837
#
# [1837 rows x 3 columns]

# %% [markdown]
# Ghi vào file excel

# %%
dataStreet.to_csv(r'sample_data/streetData.csv', index=False)
